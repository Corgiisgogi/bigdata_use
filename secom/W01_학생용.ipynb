# %% [markdown]
# # 1주차 · 장비 데이터 탐색
# 데이터: UCI SECOM (실제 웨이퍼 팹 계측 데이터)
#
# ---
#
# ## 오늘의 상황
#
# 여러분은 반도체 팹의 장비 데이터 분석 담당자입니다. 생산 라인 장비들이 웨이퍼 한 장을
# 처리할 때마다 590개의 센서 신호를 남기고, 그 웨이퍼는 최종 검사에서 양품(PASS) 또는
# 불량(FAIL) 판정을 받습니다.
#
# 공정팀에서 이런 요청이 왔습니다.
#
# > 불량이 나는 웨이퍼는 장비 신호가 뭔가 다를 겁니다. 어떤 신호가 문제인지 찾아주세요.
#
# 오늘은 이 요청에 답하기 위해 데이터를 열어보고, 쓸 수 있는 상태로 정리하고,
# 불량과 관련이 있어 보이는 신호를 추려내는 것까지 합니다.
# 모델을 만드는 건 다음 주에 합니다.
#
# ## 규칙
#
# `# TODO` 가 붙은 셀만 작성하면 됩니다. 각 미션 뒤에 자가진단 셀이 있으니
# `[통과]` 가 뜰 때까지 스스로 고쳐보세요. 막히면 물어보되 먼저 15분은 혼자 붙들어 보세요.
# 정답을 베끼는 것보다 틀리고 고치는 과정이 점수에 반영됩니다.

# %% [markdown]
# ---
#
# ## 준비

# %%
# 이 셀은 그대로 실행하세요.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.font_manager as fm
from pathlib import Path

_have = {f.name for f in fm.fontManager.ttflist}
for _f in ['Malgun Gothic', 'AppleGothic', 'NanumGothic', 'DejaVu Sans']:
    if _f in _have:
        plt.rcParams['font.family'] = _f
        break
plt.rcParams['axes.unicode_minus'] = False
pd.set_option('display.max_columns', 30)

DATA = Path('D:/박재민/secom/secom')   # 폴더를 옮겼다면 이 줄만 고치세요

def check(name, cond, hint=''):
    if cond:
        print('[통과] ' + name)
    else:
        print('[실패] ' + name + (('  ->  ' + str(hint)) if hint else ''))

print('폰트:', plt.rcParams['font.family'][0], '| 데이터 폴더:', DATA.exists())
# Out:
# 폰트: Malgun Gothic | 데이터 폴더: True

# %% [markdown]
# ---
#
# ## 미션 1 · 데이터 열어보기
#
# 파일이 두 개 있습니다.
#
# - `secom_equipment.csv` — 웨이퍼 1,567장과 신호 590개, 그리고 양불 판정
# - `signal_metadata.csv` — 각 신호가 어느 장비 모듈의 무슨 센서인지
#
# 두 파일을 `df`, `meta` 로 불러오고, 크기와 불량 비율을 확인하세요.
# `label` 컬럼은 1이 불량, 0이 양품입니다.
#
# `timestamp` 는 날짜로 읽어야 합니다. 여기서 `parse_dates` 를 빠뜨리면
# 미션 7에서 반드시 막히니 지금 챙기세요.

# %%
# TODO 1-1: 두 파일 불러오기
#   힌트: pd.read_csv(DATA / '파일명', encoding='utf-8-sig', parse_dates=['timestamp'])
df = pd.read_csv(Path.joinpath(DATA, 'secom_equipment.csv'), encoding='utf-8-sig', parse_dates=['timestamp'])
meta = pd.read_csv(Path.joinpath(DATA, 'signal_metadata.csv'), encoding='utf-8-sig')

# TODO 1-2: 두 데이터의 크기 출력
print(df.size)
print(meta.size)

# TODO 1-3: 불량 건수와 비율(%)
n_fail = len(df.loc[df['pass_fail'] == 'FAIL'])
fail_rate = round((n_fail / len(df['pass_fail']))*100, 2)
# Out:
# 930798
# 7670

# %% [markdown]
# 자가진단 1 — 실행해서 모두 `[통과]` 인지 확인하세요.

# %%
check('데이터 로드', df is not None and meta is not None, '두 파일을 읽어오세요')
check('df 크기 1567 x 594', df is not None and df.shape == (1567, 594), None if df is None else df.shape)
check('meta 590행', meta is not None and len(meta) == 590)
check('불량 104건', n_fail == 104, n_fail)
check('불량률 6.64%', fail_rate is not None and abs(fail_rate - 6.64) < 0.05, fail_rate)
# Out:
# [통과] 데이터 로드
# [통과] df 크기 1567 x 594
# [통과] meta 590행
# [통과] 불량 104건
# [통과] 불량률 6.64%

# %% [markdown]
# ---
#
# ## 미션 2 · 결측 진단
#
# 실제 장비 데이터에는 비어 있는 값이 많습니다. 센서가 고장 났거나, 그 레시피에서는
# 아예 측정하지 않는 항목이거나, 통신이 끊긴 경우입니다.
#
# 신호별로 얼마나 비어 있는지 재고, 절반 넘게 비어 있는 신호를 추려내세요.
# 절반 이상 비어 있으면 채워 넣어도 대부분이 지어낸 값이 되기 때문에 버리는 편이 낫습니다.

# %%
# TODO 2-1: SIG_ 로 시작하는 컬럼 이름만 모으기
sig_cols = df.filter(like="SIG_").columns

# TODO 2-2: 신호별 결측 비율 (힌트: .isna().mean())
miss = df.filter(like="SIG_").isna().mean()

# TODO 2-3: 결측이 많은 상위 10개 출력
print(miss.sort_values(ascending=False).head(10))

# TODO 2-4: 결측 50%를 넘는 신호 이름 리스트
high_missing = miss[miss > 0.5].index
# Out:
# SIG_158    0.911934
# SIG_293    0.911934
# SIG_294    0.911934
# SIG_159    0.911934
# SIG_493    0.855775
# SIG_359    0.855775
# SIG_221    0.855775
# SIG_086    0.855775
# SIG_518    0.649649
# SIG_519    0.649649
# dtype: float64

# %% [markdown]
# 자가진단 2 — 실행해서 모두 `[통과]` 인지 확인하세요.

# %%
check('신호 590개', sig_cols is not None and len(sig_cols) == 590, None if sig_cols is None else len(sig_cols))
check('결측 비율 계산', miss is not None and abs(miss.mean() - 0.0454) < 0.001)
check('50% 초과 28개', high_missing is not None and len(high_missing) == 28, None if high_missing is None else len(high_missing))
# Out:
# [통과] 신호 590개
# [통과] 결측 비율 계산
# [통과] 50% 초과 28개

# %% [markdown]
# ---
#
# ## 미션 3 · 쓸모없는 신호 걸러내기
#
# 값이 처음부터 끝까지 똑같은 신호가 있습니다. 1,567장 내내 항상 100.0 인 식입니다.
# 이런 신호는 양품이든 불량이든 구별해 주지 못하니 빼고 갑니다.
#
# 미션 2에서 추린 것과 합쳐 제거 목록을 만드세요.
# 두 리스트를 그냥 이어 붙이지 말고 집합으로 합쳐야 합니다. 겹치는 신호가 있을 수 있으니까요.

# %%
# TODO 3-1: 값이 항상 같은 신호 찾기 (힌트: .nunique())
const_cols = df.columns[df.nunique(dropna=True) == 1]

# TODO 3-2: 제거 목록 합치기 (중복 없이)
drop_cols = const_cols.join(high_missing, how='outer')

# TODO 3-3: 남는 신호
keep_cols = sig_cols.drop(drop_cols)

# %% [markdown]
# 자가진단 3 — 실행해서 모두 `[통과]` 인지 확인하세요.

# %%
check('상수 신호 116개', const_cols is not None and len(const_cols) == 116, None if const_cols is None else len(const_cols))
check('제거 144개', drop_cols is not None and len(drop_cols) == 144, '결측 28 + 상수 116')
check('사용 446개', keep_cols is not None and len(keep_cols) == 446, None if keep_cols is None else len(keep_cols))
# Out:
# [통과] 상수 신호 116개
# [통과] 제거 144개
# [통과] 사용 446개

# %% [markdown]
# ---
#
# ## 미션 4 · 남은 결측 채우기
#
# 남은 446개 신호에도 결측이 조금씩 있습니다. 이건 버리기 아까우니 채웁니다.
#
# 무난한 방법은 그 신호의 중앙값으로 채우는 것입니다. 평균이 아니라 중앙값을 쓰는 이유는
# 센서 값에 크게 튀는 값이 섞여 있어도 덜 흔들리기 때문입니다.

# %%
# TODO 4-1: 중앙값으로 채우기
#   힌트: X = df[keep_cols].fillna( ... .median())
X = df[keep_cols].fillna(df[keep_cols].median())

# TODO 4-2: 남은 결측 개수와 X 크기 출력
print(X.isna().sum().sum(),'개,', X.shape)
# Out:
# 0 개, (1567, 446)

# %% [markdown]
# 자가진단 4 — 실행해서 모두 `[통과]` 인지 확인하세요.

# %%
check('X 생성', X is not None)
check('X 크기 1567 x 446', X is not None and X.shape == (1567, 446), None if X is None else X.shape)
check('결측 0개', X is not None and int(X.isna().sum().sum()) == 0)
# Out:
# [통과] X 생성
# [통과] X 크기 1567 x 446
# [통과] 결측 0개

# %% [markdown]
# ---
#
# ## 미션 5 · 장비 모듈별로 나눠보기
#
# `meta` 에는 각 신호가 어느 장비 모듈의 무슨 센서인지 적혀 있습니다.
# 모듈은 챔버, RF전원, 진공, 가스공급, 정전척, 온도제어, 이송, 계측 여덟 가지입니다.
#
# 전처리 후 살아남은 신호가 모듈별로 몇 개씩인지 세고 막대그래프로 그리세요.
#
# 한 가지 알아둘 것이 있습니다. 이 모듈·센서 이름은 수업용으로 붙인 가상의 이름입니다.
# SECOM 원본은 신호가 익명화되어 있어서 실제로 어떤 센서인지는 공개되지 않았습니다.
# 미션 8에서 이 점을 다시 다룹니다.

# %%
# TODO 5-1: 남은 신호의 메타데이터만 추출 (힌트: .isin())
meta_columns = X.columns
meta_keep = meta[meta['signal_id'].isin(meta_columns)]

# TODO 5-2: 모듈별 개수 세기 (힌트: value_counts)
by_module = meta_keep.value_counts(subset='module_code')

# TODO 5-3: 막대그래프. 제목과 축 이름을 꼭 넣으세요
x = np.arange(8)
print(meta_keep.values)
plt.bar(x, by_module)
plt.xticks(x, by_module.index)
plt.xlabel('module name')
plt.ylabel('count')
plt.title('Kept module count')
plt.show()
# Out:
# [['SIG_001' 'CHAMBER' '챔버' ... 2743.24 3356.35 '교육용 가상 매핑(원본은 익명화 신호)']
#  ['SIG_002' 'RF' 'RF전원' ... 2158.75 2846.44 '교육용 가상 매핑(원본은 익명화 신호)']
#  ['SIG_003' 'VACUUM' '진공' ... 2060.66 2315.2667 '교육용 가상 매핑(원본은 익명화 신호)']
#  ...
#  ['SIG_588' 'GAS_MFC' '가스공급' ... 0.0032 0.0799 '교육용 가상 매핑(원본은 익명화 신호)']
#  ['SIG_589' 'ESC' '정전척' ... 0.001 0.0286 '교육용 가상 매핑(원본은 익명화 신호)']
#  ['SIG_590' 'THERMAL' '온도제어' ... 0.0 737.3048 '교육용 가상 매핑(원본은 익명화 신호)']]

# %% [markdown]
# 자가진단 5 — 실행해서 모두 `[통과]` 인지 확인하세요.

# %%
check('meta_keep 446행', meta_keep is not None and len(meta_keep) == 446, None if meta_keep is None else len(meta_keep))
check('모듈 8종', by_module is not None and len(by_module) == 8)
# Out:
# [통과] meta_keep 446행
# [통과] 모듈 8종

# %% [markdown]
# ---
#
# ## 미션 6 · 불량 관련 신호 Top 10 찾기
#
# 오늘의 본론입니다.
#
# 불량 웨이퍼와 양품 웨이퍼의 신호 값을 비교해서 차이가 큰 신호를 찾습니다.
# 그런데 신호마다 단위가 다릅니다. 어떤 건 3000 언저리이고 어떤 건 0.1 언저리입니다.
# 그냥 빼서 비교하면 값이 큰 신호가 무조건 이깁니다.
#
# 그래서 표준편차로 나눠줍니다. 이렇게 하면 단위가 사라져서 신호끼리 공정하게 비교됩니다.
# 이 값을 효과크기라고 부릅니다.
#
# ```
# 효과크기 = | (불량 평균 - 양품 평균) / 전체 표준편차 |
# ```
#
# 표준편차가 0인 신호는 0으로 나누게 되니 `np.nan` 으로 바꿔두고 계산하세요.

# %%
# TODO 6-1: 불량 마스크
#meta_keep = meta[meta['signal_id'].isin(meta_columns)]
df_keep = df[df['SIG_001'].isin(X['SIG_001'])]
is_fail = df_keep.loc[df['pass_fail'] == 'FAIL']

# TODO 6-2: 그룹별 평균
mean_fail = None
mean_pass = None

# TODO 6-3: 효과크기 (절댓값, 큰 순서로 정렬)
effect = None

# TODO 6-4: Top 10 을 meta 와 합쳐 표로 출력
top10 = None


# TODO 6-5: 1등 신호의 양품 vs 불량 박스플롯
# Out:
#      wafer_id           timestamp pass_fail  label  SIG_001  SIG_002  \
# 2      W00003 2008-07-19 13:17:00      FAIL      1  2932.61  2559.94
# 10     W00011 2008-07-19 21:57:00      FAIL      1  2994.05  2548.21
# 11     W00012 2008-07-19 22:52:00      FAIL      1  2928.84  2479.40
# 14     W00015 2008-07-21 11:53:00      FAIL      1  2963.97  2629.48
# 23     W00024 2008-07-25 15:23:00      FAIL      1  2884.74  2514.54
# ...       ...                 ...       ...    ...      ...      ...
# 1365   W01366 2008-10-06 15:00:00      FAIL      1  2988.39  2493.72
# 1400   W01401 2008-10-07 13:10:00      FAIL      1  3052.98  2515.51
# 1438   W01439 2008-10-09 04:34:00      FAIL      1  2951.84  2477.13
# 1443   W01444 2008-10-09 15:55:00      FAIL      1  3173.18  2428.64
# 1519   W01520 2008-10-15 02:42:00      FAIL      1  2903.34  2585.48
#
#         SIG_003    SIG_004  SIG_005  SIG_006   SIG_007  SIG_008  SIG_009  \
# 2     2186.4111  1698.0172   1.5102    100.0   95.4878   0.1241   1.4436
# 10    2195.1222  1046.1468   1.3204    100.0  103.3400   0.1223   1.5144
# 11    2196.2111  1605.7578   0.9959    100.0   97.9156   0.1257   1.4690
# 14    2224.6222   947.7739   1.2924    100.0  104.8489   0.1197   1.4474
# 23    2160.3667   899.9488   1.4022    100.0  105.4978   0.1240   1.5585
# ...         ...        ...      ...      ...       ...      ...      ...
# 1365  2206.4000   982.5452   1.1853    100.0  116.8167   0.1228   1.5279
# 1400  2172.8111   969.3436   1.2736    100.0  102.7367   0.1243   1.4065
# 1438  2192.1889  1435.9611   2.3870    100.0  107.3989   0.1229   1.4613
# 1443  2209.4667  1556.3930   1.4884    100.0   95.1156   0.1206   1.6073
# 1519  2196.1111  1472.6400   1.5599    100.0   94.6522   0.1212   1.5134
#
#       SIG_010  SIG_011  ...  SIG_576  SIG_577  SIG_578  SIG_579  SIG_580  \
# 2      0.0041   0.0013  ...   0.0640   2.0952   9.2721   0.0584   0.0484
# 10    -0.0190   0.0013  ...   0.0862   1.7983  14.5507   0.0355   0.0205
# 11     0.0170  -0.0154  ...   0.0841   1.4501  12.8058   0.0370   0.0279
# 14     0.0144  -0.0119  ...   0.1163   2.1440  16.1875   0.0202   0.0289
# 23    -0.0317  -0.0138  ...   0.0503   1.6343   8.4505   0.0098   0.0213
# ...       ...      ...  ...      ...      ...      ...      ...      ...
# 1365  -0.0094   0.0001  ...   0.0898   1.6997  13.8979  -0.0006   0.0118
# 1400  -0.0037  -0.0058  ...   0.0396   1.0597  13.1807   0.0302   0.0159
# 1438  -0.0027  -0.0039  ...   0.0849   1.7170  12.6938      NaN      NaN
# 1443  -0.0278  -0.0057  ...   0.0849   1.3580  12.2013   0.0281   0.0247
# 1519   0.0036  -0.0055  ...   0.1105   1.8913  16.4099   0.0157   0.0134
#
#       SIG_581   SIG_582  SIG_583  SIG_584  SIG_585  SIG_586  SIG_587  SIG_588  \
# 2      0.0148   82.8602   0.4958   0.0157   0.0039   3.1745   0.0584   0.0484
# 10     0.0071   57.8122   0.4925   0.0158   0.0041   3.2115   0.0355   0.0205
# 11     0.0081   75.5077   0.4987   0.0427   0.0092   8.5646   0.0370   0.0279
# 14     0.0084  142.9080   0.5077   0.0094   0.0026   1.8483   0.0202   0.0289
# 23     0.0077  216.8869   0.4982   0.0099   0.0027   1.9771   0.0098   0.0213
# ...       ...       ...      ...      ...      ...      ...      ...      ...
# 1365   0.0039    0.0000   0.4972   0.0154   0.0035   3.0992  -0.0006   0.0118
# 1400   0.0059   52.7014   0.5081   0.0158   0.0037   3.1106   0.0302   0.0159
# 1438      NaN       NaN   0.4969   0.0118   0.0037   2.3773   0.0178   0.0120
# 1443   0.0075   88.1528   0.5021   0.0192   0.0041   3.8289   0.0281   0.0247
# 1519   0.0043   85.3122   0.4979   0.0176   0.0040   3.5250   0.0157   0.0134
#
#       SIG_589   SIG_590
# 2      0.0148   82.8602
# 10     0.0071   57.8122
# 11     0.0081   75.5077
# 14     0.0084  142.9080
# 23     0.0077  216.8869
# ...       ...       ...
# 1365   0.0039    0.0000
# 1400   0.0059   52.7014
# 1438   0.0038   67.7994
# 1443   0.0075   88.1528
# 1519   0.0043   85.3122
#
# [104 rows x 594 columns]

# %% [markdown]
# 자가진단 6 — 실행해서 모두 `[통과]` 인지 확인하세요.

# %%
check('불량 104건', is_fail is not None and int(is_fail.sum()) == 104)
check('효과크기 계산', effect is not None and len(effect.dropna()) > 400)
check('1위 SIG_060', top10 is not None and top10.index[0] == 'SIG_060', None if top10 is None else top10.index[0])
check('2위 SIG_104', top10 is not None and top10.index[1] == 'SIG_104')
check('1위 효과크기 0.627', top10 is not None and abs(top10.iloc[0] - 0.6265) < 0.01)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[219], line 1
# ----> 1 check('불량 104건', is_fail is not None and int(is_fail.sum()) == 104)
#       2 check('효과크기 계산', effect is not None and len(effect.dropna()) > 400)
#       3 check('1위 SIG_060', top10 is not None and top10.index[0] == 'SIG_060', None if top10 is None else top10.index[0])
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11697, in DataFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   11688 @doc(make_doc("sum", ndim=2))
#   11689 def sum(
#   11690     self,
#    (...)  11695     **kwargs,
#   11696 ):
# > 11697     result = super().sum(axis, skipna, numeric_only, min_count, **kwargs)
#   11698     return result.__finalize__(self, method="sum")
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12571, in NDFrame.sum(self, axis, skipna, numeric_only, min_count, **kwargs)
#   12563 def sum(
#   12564     self,
#   12565     axis: Axis | None = 0,
#    (...)  12569     **kwargs,
#   12570 ):
# > 12571     return self._min_count_stat_function(
#   12572         "sum", nanops.nansum, axis, skipna, numeric_only, min_count, **kwargs
#   12573     )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\generic.py:12554, in NDFrame._min_count_stat_function(self, name, func, axis, skipna, numeric_only, min_count, **kwargs)
#   12551 elif axis is lib.no_default:
#   12552     axis = 0
# > 12554 return self._reduce(
#   12555     func,
#   12556     name=name,
#   12557     axis=axis,
#   12558     skipna=skipna,
#   12559     numeric_only=numeric_only,
#   12560     min_count=min_count,
#   12561 )
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11589, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11585     df = df.T
#   11587 # After possibly _get_data and transposing, we are now in the
#   11588 #  simple case where we can use BlockManager.reduce
# > 11589 res = df._mgr.reduce(blk_func)
#   11590 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11591 if out_dtype is not None and out.dtype != "boolean":
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\managers.py:1519, in BlockManager.reduce(self, func)
#    1517 res_blocks: list[Block] = []
#    1518 for blk in self.blocks:
# -> 1519     nbs = blk.reduce(func)
#    1520     res_blocks.extend(nbs)
#    1522 index = Index([None])  # placeholder
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\internals\blocks.py:406, in Block.reduce(self, func)
#     400 @final
#     401 def reduce(self, func) -> list[Block]:
#     402     # We will apply the function and reshape the result into a single-row
#     403     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     404     assert self.ndim == 2
# --> 406     result = func(self.values)
#     408     if self.values.ndim == 1:
#     409         res_values = result
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\frame.py:11490, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11486 if isinstance(values, ExtensionArray):
#   11487     if not is_1d_only_ea_dtype(values.dtype) and not isinstance(
#   11488         self._mgr, ArrayManager
#   11489     ):
# > 11490         return values._reduce(name, axis=1, skipna=skipna, **kwds)
#   11491     has_keepdims = dtype_has_keepdims.get(values.dtype)
#   11492     if has_keepdims is None:
#
# File c:\Users\user\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\arrays\base.py:1954, in ExtensionArray._reduce(self, name, skipna, keepdims, **kwargs)
#    1952 meth = getattr(self, name, None)
#    1953 if meth is None:
# -> 1954     raise TypeError(
#    1955         f"'{type(self).__name__}' with dtype {self.dtype} "
#    1956         f"does not support reduction '{name}'"
#    1957     )
#    1958 result = meth(skipna=skipna, **kwargs)
#    1959 if keepdims:
#
# TypeError: 'DatetimeArray' with dtype datetime64[ns] does not support reduction 'sum'

# %% [markdown]
# ---
#
# ## 미션 7 · 시간에 따른 불량률 변화
#
# 장비는 시간이 지나면서 상태가 변합니다. 소모품이 닳고, 챔버가 오염되고, 정기점검을 받습니다.
# 예지보전의 출발점은 불량이 언제 몰렸는지 보는 것입니다.
#
# 월별로 처리량과 불량률을 집계하고 선그래프로 그리세요.
# 그래프를 보면서 미션 8에서 뭐라고 쓸지 생각해 두세요.

# %%
# TODO 7-1: 월 단위 컬럼 만들기
#   힌트: df['timestamp'].dt.to_period('M')
#   (아래에 직접 작성하세요)


# TODO 7-2: 월별 처리량 / 불량수 / 불량률
monthly = None

# TODO 7-3: 월별 불량률 선그래프

# %% [markdown]
# 자가진단 7 — 실행해서 모두 `[통과]` 인지 확인하세요.

# %%
check('month 컬럼', df is not None and 'month' in df.columns and df['month'].notna().all())
check('4개월 집계', monthly is not None and len(monthly) == 4, '2008년 7~10월')
check('7월이 가장 높음', monthly is not None and monthly['불량률'].idxmax() == monthly.index[0])

# %% [markdown]
# ---
#
# ## 미션 8 · 정리해서 쓰기
#
# 여기부터는 코드가 아니라 글입니다. 아래 항목을 본인 문장으로 채우세요.
# 숫자를 근거로 인용해야 합니다. 446개, 6.64% 같은 식으로요.
#
# ---
#
# **1. 데이터가 어떤 것이었나**
#
# 웨이퍼 몇 장, 신호 몇 개, 불량률은 얼마였습니까.
#
# 답:
#
# **2. 무엇을 왜 버렸나**
#
# 590개 중 144개를 뺐습니다. 어떤 기준으로 뺐고, 그 기준이 왜 타당합니까.
#
# 답:
#
# **3. 어떤 신호가 걸렸나**
#
# Top 10에 어느 모듈이 많이 나왔습니까. 1등 신호의 박스플롯에서 무엇이 보였습니까.
#
# 답:
#
# **4. 시간에 따라 어떻게 변했나**
#
# 월별 불량률이 어떻게 움직였고, 원인으로 무엇을 의심할 수 있습니까.
#
# 답:
#
# **5. 공정팀에 보내는 한 문단**
#
# 어느 모듈을 먼저 점검하라고 권하겠습니까. 근거를 넣어 한 문단으로 쓰세요.
#
# 답:
#
# **6. 이 분석으로 말할 수 없는 것**
#
# 이 결과만으로 단정할 수 없는 이유를 최소 두 가지 쓰세요.
# 효과크기가 크면 그 신호가 원인입니까. 불량 104건은 충분합니까. 신호 이름은 진짜입니까.
#
# 답:

# %% [markdown]
# ---
#
# ### 제출 전 확인
#
# - [ ] 자가진단이 모두 `[통과]` 인가
# - [ ] 그래프 세 개(막대·박스·선)에 제목과 축 이름이 있는가
# - [ ] 미션 8의 여섯 항목을 본인 문장으로 채웠는가
# - [ ] 커널 재시작 후 전체 실행이 오류 없이 끝나는가
# - [ ] 파일명을 `W01_학번_이름.ipynb` 로 바꿨는가
